# %% [markdown]
# <a href="https://colab.research.google.com/github/ibnuhajar/Computer_Vision/blob/master/Histogram_peppers_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import matplotlib.pyplot as plt

citra = cv.imread('peppers.png')
histo = cv.calcHist([citra], [2], None, [256], [0,256])
plt.plot(histo)
plt.show()
